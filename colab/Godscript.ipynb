# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/collab/tumai/newanalysis
# Out:
# /content/gdrive/MyDrive/collab/tumai/newanalysis

# %%
ls
# Out:
#  A0KX894_hr.csv
#  A0L9BM2_hr.csv
#  A0N9NV4_hr.csv
#  A0NVTRV_hr.csv
#  A0VFT1N_hr.csv
#  A1K5DRI_hr.csv
#  A2D7K4A_hr.csv
#  A4E0D03_hr.csv
#  AAXAA7Z_hr.csv
#  AKXN5ZZ_hr.csv
#  analysis_sick_person_A4E0D03_hr.ipynb
# 'Copy of analysis_sick_person_Akxn5ZZ_hr.ipynb'
# 'Copy of Copy of analysis_sick_person_AAXAA7Z_hr.ipynb'
#  data_treated_A0KX894_quality_0.871367814362184.csv
#  data_treated_A0N9NV4_quality_0.8315445065359504.csv
#  data_treated_A4E0D03_quality_0.662608422280227_10000khz.csv
#  data_treated_AAXAA7Z_quality_0.9017821078686461_10000khz.csv
#  data_treated_AKXN5ZZ_quality_0.8271026088591573_10000khz.csv
#  Godscript.ipynb
#  labelsxlsx.xlsx
#  notebook_autoanalysis_not_coronaindiv.ipynb
#  preprocessed_signal.csv

# %%
import pandas as pd

# %%
data=pd.read_csv("data_treated_AKXN5ZZ_quality_0.8271026088591573_10000khz.csv")

# %%
data
# Out:
#         Unnamed: 0  ECG_Raw  ECG_Clean    ECG_Rate  ECG_Quality  ECG_R_Peaks  \
# 0                0       70  -0.336810   80.156493     0.933049            0
# 1                1       69  -0.252058   80.156493     0.933049            0
# 2                2       69  -0.167307   80.156493     0.933049            0
# 3                3       71  -0.082557   80.156493     0.933049            0
# 4                4       72  -0.010309   80.156493     0.933049            0
# ...            ...      ...        ...         ...          ...          ...
# 827955      827955       66   5.139819  112.570356     0.796872            0
# 827956      827956       66   4.940949  112.570356     0.796872            0
# 827957      827957       66   4.742176  112.570356     0.796872            0
# 827958      827958       66   4.543469  112.570356     0.796872            0
# 827959      827959       66   4.344796  112.570356     0.796872            0
#
#                    datetime     user
# ...

# %%
data = data.drop(columns='Unnamed: 0',axis=1)

# %%
df_labels=pd.read_excel('labelsxlsx.xlsx',sheet_name='SuppTable3_Fig2a_COVID-19',skiprows=3)
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
user=data["user"][0]

# %%
df_labels
# Out:
#         ParticipantID                     Category  \
# 0             AFPB8J2                     COVID-19
# 1             APGIB2T                     COVID-19
# 2             A0KX894                Other Illness
# 3             AQC0L71                     COVID-19
# 4             A0NVTRV                     COVID-19
# 5             AOYM4KG                     COVID-19
# 6             AR4FPCC                Other Illness
# 7             A4G0044                     COVID-19
# 8             AUILKHG                Other Illness
# 9             AD77K91                Other Illness
# 10            A3OU183                     COVID-19
# 11            AX6281V                     COVID-19
# 12            A4E0D03                     COVID-19
# 13            AS2MVDL                     COVID-19
# 14            AKXN5ZZ                     COVID-19
# 15            AF3J1YC  Other Illness (Influenza B)
# 16            AJWW3IY                     COVID-19
# ...

# %%
date = df_labels.loc[df_labels.ParticipantID==user,'Symptom_dates']
date= date.iloc[0]

# %%
data["Symptom_dates"]=date.split(" ")[0].split("'")[1]

# %%
data.head()
# Out:
#    ECG_Raw  ECG_Clean   ECG_Rate  ECG_Quality  ECG_R_Peaks  \
# 0       70  -0.336810  80.156493     0.933049            0
# 1       69  -0.252058  80.156493     0.933049            0
# 2       69  -0.167307  80.156493     0.933049            0
# 3       71  -0.082557  80.156493     0.933049            0
# 4       72  -0.010309  80.156493     0.933049            0
#
#               datetime     user Symptom_dates
# 0  2027-12-01 00:00:02  AKXN5ZZ    2028-01-16
# 1  2027-12-01 00:00:07  AKXN5ZZ    2028-01-16
# 2  2027-12-01 00:00:22  AKXN5ZZ    2028-01-16
# 3  2027-12-01 00:00:27  AKXN5ZZ    2028-01-16
# 4  2027-12-01 00:00:32  AKXN5ZZ    2028-01-16
